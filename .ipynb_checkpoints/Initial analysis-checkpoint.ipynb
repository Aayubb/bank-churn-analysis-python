# %%
# Importing libraries and reading csv file
import pandas as pd

churn_df = pd.read_csv('csv_files/churn_data.csv')
churn_df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# ...

# %%
churn_df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
churn_df.isna().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %% [markdown]
# ##### What does it mean for a customer to churn?
# - Customer churn means the rate of customers stopping to do business with a company over a time period.
#
# ##### Why does a bank care about this?
# - Because losing a customer means sacrificing long-term interest income, account fees, and cross-selling opportunities.
#
# ##### What might cause a customer to leave?
# - Poor customer service, high or hidden fees, and the lure of better competitor rates

# %%
# Droppping irrelevant columns
relevant_df =churn_df.drop(columns = ['CustomerId', 'Surname'])
relevant_df.head()
# Out:
#    RowNumber  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0          1          619    France  Female   42       2       0.00
# 1          2          608     Spain  Female   41       1   83807.86
# 2          3          502    France  Female   42       8  159660.80
# 3          4          699    France  Female   39       1       0.00
# 4          5          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    Complain  Satisfaction Score Card Type  Point Earned
# 0         1                   2   DIAMOND           464
# ...

# %%
# Checking for duplicates

relevant_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Creating bins for ages.
# The Age column is a continuous number, but for analysis it is more useful to group customers into brackets.

bins=[0, 30, 40, 50, 60, 100]
labels=['18-30', '31-40', '41-50', '51-60', '60+']

relevant_df['Age_Group'] = pd.cut(relevant_df['Age'], bins=bins, labels=labels, right=False)

relevant_df['Age_Group'].head()
# Out:
# 0    41-50
# 1    41-50
# 2    41-50
# 3    31-40
# 4    41-50
# Name: Age_Group, dtype: category
# Categories (5, str): ['18-30' < '31-40' < '41-50' < '51-60' < '60+']

# %%
# Creating bins for balance.
bins = [0, 1,80000,160000, float('inf')]
labels = ['Zero Balance', 'Low', 'Medium', 'High']

relevant_df['Balance_Group'] = pd.cut(relevant_df['Balance'], bins= bins, labels= labels, include_lowest=True  )
relevant_df['Balance_Group'].head()
# Out:
# 0    Zero Balance
# 1          Medium
# 2          Medium
# 3    Zero Balance
# 4          Medium
# Name: Balance_Group, dtype: category
# Categories (4, str): ['Zero Balance' < 'Low' < 'Medium' < 'High']

# %%
relevant_df['Age_Group'].value_counts()
# Out:
# Age_Group
# 31-40    4346
# 41-50    2618
# 18-30    1641
# 51-60     869
# 60+       526
# Name: count, dtype: int64

# %%
# Label encoding gender
from sklearn.preprocessing import LabelEncoder

# %%
le_gender = LabelEncoder()
relevant_df['Gender'] = le_gender.fit_transform(relevant_df['Gender'])

# %%
print(relevant_df['Gender'].unique())

# Female- 0
# Male - 1
# Out:
# [0 1]

# %%
relevant_df.head()
# Out:
#    RowNumber  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0          1          619    France       0   42       2       0.00
# 1          2          608     Spain       0   41       1   83807.86
# 2          3          502    France       0   42       8  159660.80
# 3          4          699    France       0   39       1       0.00
# 4          5          850     Spain       0   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    Complain  Satisfaction Score Card Type  Point Earned Age_Group  \
# 0         1                   2   DIAMOND           464     41-50
# ...

# %% [markdown]
# #### Exploratory data analysis
#
# ##### Uncovering churn patterns across every key variable

# %% [markdown]
# ##### 1. Calaulating the overall churn rate
#
# Formula = (total churned / total customers) * 100

# %%
relevant_df['Churn'] = relevant_df['Exited']
relevant_df.head()
# Out:
#    RowNumber  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0          1          619    France       0   42       2       0.00
# 1          2          608     Spain       0   41       1   83807.86
# 2          3          502    France       0   42       8  159660.80
# 3          4          699    France       0   39       1       0.00
# 4          5          850     Spain       0   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    Complain  Satisfaction Score Card Type  Point Earned Age_Group  \
# 0         1                   2   DIAMOND           464     41-50
# ...

# %%
# Overall churn rate
total_customer= len(relevant_df)
total_churned = relevant_df['Churn'].sum()
overall_churn_rate = (total_churned / total_customer) * 100

print(f"  Total Customers : {total_customer}")
print(f"  Total Churned   : {total_churned}")
print(f"  Churn Rate      : {overall_churn_rate:.2f}%\n")
# Out:
#   Total Customers : 10000
#   Total Churned   : 2038
#   Churn Rate      : 20.38%

# %% [markdown]
# #####  2. Calculating churn rate by geography

# %%
# Creating a function that calculates the churn rate of required columns

def churn_summary(df, col):
    group = df.groupby(col).agg(
         Total = ('Churn', 'count'),
        Churned = ('Churn', 'sum')
    ).reset_index()

    group['churn_rate_%'] = (group['Churned'] / group['Total'])  * 100

    return group

# %%
geo_summary = churn_summary(relevant_df, 'Geography')

print('Churn rate by geography:')
print('-' * 50)
print(geo_summary.to_string(index= False))
# Out:
# Churn rate by geography:
# --------------------------------------------------
# Geography  Total  Churned  churn_rate_%
#    France   5014      811     16.174711
#   Germany   2509      814     32.443204
#     Spain   2477      413     16.673395

# %% [markdown]
# ##### 3. Calculating churn rate by gender

# %%
gender_summary = churn_summary(relevant_df, 'Gender')

print('Churn rate by gender:')
print('-' * 50)
print(gender_summary.to_string(index= False))
# Out:
# Churn rate by gender:
# --------------------------------------------------
#  Gender  Total  Churned  churn_rate_%
#       0   4543     1139     25.071539
#       1   5457      899     16.474253

# %% [markdown]
# ##### 4. Calculating churn rate by AgeGroup

# %%
age_summary = churn_summary(relevant_df, 'Age_Group')

print('Churn rate by Age Group:')
print('-' * 50)
print(age_summary.to_string(index= False))
# Out:
# Churn rate by Age Group:
# --------------------------------------------------
# Age_Group  Total  Churned  churn_rate_%
#     18-30   1641      124      7.556368
#     31-40   4346      473     10.883571
#     41-50   2618      807     30.825057
#     51-60    869      487     56.041427
#       60+    526      147     27.946768

# %% [markdown]
# ##### 5. Calclating churn rate by Number of products

# %%
product_summary = churn_summary(relevant_df, 'NumOfProducts')

print('Churn rate by Number of producst:')
print('-' * 50)
print(product_summary.to_string(index= False))
# Out:
# Churn rate by Number of producst:
# --------------------------------------------------
#  NumOfProducts  Total  Churned  churn_rate_%
#              1   5084     1409     27.714398
#              2   4590      349      7.603486
#              3    266      220     82.706767
#              4     60       60    100.000000

# %% [markdown]
# ##### 6. Calculating churn rate by Active Member Status

# %%
## relevant_df['ActiveStatus'] = relevant_df['IsActiveMember'].map({1: 'Active', 0: 'Inactive'})
member_status_summary = churn_summary(relevant_df, 'IsActiveMember')

print('Churn rate by Active member status: ')
print('-' * 50)
print(member_status_summary.to_string(index= False))
# Out:
# Churn rate by Active member status:
# --------------------------------------------------
#  IsActiveMember  Total  Churned  churn_rate_%
#               0   4849     1303     26.871520
#               1   5151      735     14.269074

# %% [markdown]
# #### Analyzing numerical features and correlations

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style('whitegrid')

# %% [markdown]
# ##### Checking distribution of Numerical Features by Churn Status

# %%
# Histogram

fig, ax = plt.subplots(2, 2, figsize=(10, 10))
sns.histplot(data =relevant_df, x='CreditScore', ax=ax[0,0], hue='Churn')
sns.histplot(data =relevant_df, x='Age', ax=ax[0,1], hue='Churn')
sns.histplot(data =relevant_df, x='Balance', ax=ax[1,0], hue='Churn')
sns.histplot(data =relevant_df, x='EstimatedSalary', ax=ax[1,1], hue='Churn')

fig.suptitle('Histogram of numerical features')
ax[0,0].xaxis.set_label_text("Credit Score ")
ax[0,1].xaxis.set_label_text("Age ")
ax[1,0].xaxis.set_label_text("balance")
ax[1,1].xaxis.set_label_text("Estimated salary")
plt.show()

# %%
# kdeplot(Kernel Density Estimate plot) 

fig_2, ax_2= plt.subplots(2, 2, figsize=(10, 10))

sns.kdeplot(data=relevant_df, x='CreditScore', y=None, hue='Churn', fill= False, ax= ax_2[0,0])
sns.kdeplot(data=relevant_df, x='Age', y=None, hue='Churn', fill= False, ax= ax_2[0,1])
sns.kdeplot(data=relevant_df, x='Balance', y=None, hue='Churn', fill= False, ax= ax_2[1,0])
sns.kdeplot(data=relevant_df, x='EstimatedSalary', y=None, hue='Churn', fill= False, ax=ax_2[1,1])

fig_2.suptitle('Kdeplot of numerical features')
ax_2[0,0].xaxis.set_label_text("Credit Score ")
ax_2[0,1].xaxis.set_label_text("Age ")
ax_2[1,0].xaxis.set_label_text("Balance")
ax_2[1,1].xaxis.set_label_text("Estimated salary")

ax_2[1,0].tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# #### Correlation Heatmap

# %%
corr_calculation= relevant_df.select_dtypes(int).corr()
sns.heatmap(corr_calculation)
# Out:
# <Axes: >

# %% [markdown]
# #### Box Plots for Numerical Features by Churn

# %%
sns.boxplot(x='Churn', y='CreditScore', data=relevant_df)
# Out:
# <Axes: xlabel='Churn', ylabel='CreditScore'>

# %%
sns.boxplot(x='Churn', y='Age', data=relevant_df)
# Out:
# <Axes: xlabel='Churn', ylabel='Age'>

# %%
sns.boxplot(x='Churn', y='Balance', data=relevant_df)
# Out:
# <Axes: xlabel='Churn', ylabel='Balance'>

# %% [markdown]
# ### Findings

# %% [markdown]
# #### 1. In Germany the churn rate is 32.44%, compared to the overall rate of 20.38%. Germany is almost double the average, suggesting structural observation and changes in Germany

# %% [markdown]
# #### 2. Females(25%) tend to churn more than male(16%), suggesting on reflection on how the bank treats female and male customers.

# %% [markdown]
# #### 3. 27% of the customers are inactive members churns, which is almost twice than the active members (14%). This has a business implication, suggesting if we can re-engage these inactive members to reduce churn.

# %% [markdown]
# ## Visualizations & Interactive Dashboard

# %% [markdown]
# #### Churn Rate by Geography

# %%
churn_pct = relevant_df.groupby('Geography')['Churn'].mean() * 100
overall_churn_pct = relevant_df['Churn'].mean() * 100

fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(data=churn_pct.reset_index(), x='Geography', y='Churn',
            palette=['#2ecc71', '#e74c3c', '#3498db'], hue='Geography')
plt.axhline(y=overall_churn_pct, linestyle='dashed')


for bar in ax.patches:
    x = bar.get_x() + bar.get_width() / 2  
    y = bar.get_height()      

    ax.text(x, y+0.5, f'{y:.1f}%', ha='center')
    
   
plt.title('Churn rate by Grography')
plt.xlabel('Geography')
plt.ylabel('Churn rate (%)')

plt.savefig('imgs/Geography_churn_rate.png', dpi=150, bbox_inches='tight')

plt.show()

# %% [markdown]
# #### Churn Rate by AgeGroup

# %%
churn_pct = relevant_df.groupby('Age_Group')['Churn'].mean() * 100
overall_churn_pct = relevant_df['Churn'].mean() * 100

fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(data=churn_pct.reset_index() , x='Age_Group', y='Churn', hue='Age_Group',
           order= ['18-30', '31-40', '41-50', '51-60', '60+'])
plt.axhline(y=overall_churn_pct, linestyle='dashed')

for bar in ax.patches:
    x = bar.get_x() + bar.get_width() / 2  
    y = bar.get_height()      

    ax.text(x, y+0.5, f'{y:.1f}%', ha='center')



plt.title('Churn rate by Age Group')
plt.xlabel('Age Groups')
plt.ylabel('Churn rate (%)')

plt.savefig('imgs/Age_churn.png', dpi=150, bbox_inches='tight')

plt.show()

# %% [markdown]
# ####  Churn Rate by Number of Products

# %%
churn_pct = relevant_df.groupby('NumOfProducts')['Churn'].mean() * 100
overall_churn_pct = relevant_df['Churn'].mean() * 100

fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(data= churn_pct.reset_index(), x= 'NumOfProducts', y='Churn', hue='NumOfProducts')
plt.axhline(y= overall_churn_pct, linestyle= 'dashed')


for bar in ax.patches:
    x= bar.get_x() + bar.get_width() /2
    y= bar.get_height()

    ax.text(x, y+0.5, f'{y:.1f}%', ha='center')

plt.title('Churn rate by number of products')
plt.xlabel('Number of products')
plt.ylabel('Churn rate (%)')

plt.savefig('imgs/No_of_products_churn', dpi=150, bbox_inches='tight')

plt.show()

# %% [markdown]
# #### Age Distribution by Churn Status

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.kdeplot(data= relevant_df, x='Age', hue='Churn', fill=True, alpha = 0.5)

legend = ax.get_legend()
legend.get_texts()[0].set_text('Retained')
legend.get_texts()[1].set_text('Churned')

plt.title('Age Distribution by Churn Status')
plt.xlabel('Age')
plt.ylabel('Density')

plt.savefig('imgs/kde_age.png', dpi=150, bbox_inches='tight')

plt.show()

# %% [markdown]
# #### Polished Correlation Heatmap

# %%
corr_map = relevant_df.select_dtypes(include='number').corr()
fig, ax= plt.subplots(figsize=(10,6))
sns.heatmap(data=corr_map, annot= True, cmap= 'coolwarm', fmt='.2f', linewidth=0.5)
plt.xticks(rotation=45, ha='right')
plt.title('Coorelation heatmap')
plt.tight_layout()
plt.show()

plt.savefig('imgs/correlation_heatmap.png', dpi=150, bbox_inches='tight')

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ip (D:\Bank Customer Churn Analysis Dashboard\Churn\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (D:\Bank Customer Churn Analysis Dashboard\Churn\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (D:\Bank Customer Churn Analysis Dashboard\Churn\Lib\site-packages)

# %%
import plotly.express as px

# %%
fig1 = px.bar(
    data_frame=  geo_summary,
    x='Geography',
    y='churn_rate_%',
    title = 'Customer Churn Rate by Country',
    color='Geography',
    barmode='group'
)

fig1.show()

# %%
count = relevant_df['Churn'].value_counts()

df = pd.DataFrame(
    {'Labels': ['Retained', 'Churned'],
       'Values': [count[0], count[1]]
    }
)

fig2 = px.pie(
    data_frame = df,
    values = 'Values',
    names = 'Labels',
    hole = 0.3,
    title = 'Overall churn split pie chart'
)

fig2.update_traces(textinfo='label+percent')

fig2.show()

# %%
color = relevant_df['Churn'].astype(str)

fig3= px.scatter(
    data_frame = relevant_df,
    x='Age',
    y='Balance',
    hover_data=['Geography', 'CreditScore'],
    color =color,
    opacity=0.5
       
)
fig3.update_traces(
    name = 'Retained', selector=dict(name='0')
)
fig3.update_traces(
    name = 'Churned', selector=dict(name='1')
)
fig3.update_layout(
    showlegend = True,
)
fig3.show()

# %% [markdown]
# #### Exporting these plots into html

# %%
fig1.write_html('churn_dashboard.html', include_plotlyjs=True, full_html=True)

with open('churn_dashboard.html', 'a') as f:
    f.write(fig2.to_html(include_plotlyjs=False, full_html=False))
    f.write(fig3.to_html(include_plotlyjs=False, full_html=False))

# %% [markdown]
# #### Chi-Square Test on Categorical Variables

# %%
from scipy.stats import chi2_contingency

# %%
# Geography and churn
geo_table = pd.crosstab(relevant_df['Geography'], relevant_df['Churn'])

chi2, p, dof, expected = chi2_contingency(geo_table)
print(f'Geography p-value: {p:.6f}')
# Out:
# Geography p-value: 0.000000

# %%
# Age and churn
age_table = pd.crosstab(relevant_df['Age'], relevant_df['Churn'])
chi2, p, dof, expected = chi2_contingency(age_table)
print(f'Age p-value: {p:.6f}')
# Out:
# Age p-value: 0.000000

# %%
# Active members and churn
activity_table = pd.crosstab(relevant_df['IsActiveMember'], relevant_df['Churn'])
chi2, p, dof, expected = chi2_contingency(activity_table)
print(f'Active member p-value: {p:.6f}')
# Out:
# Active member p-value: 0.000000

# %% [markdown]
# #### T-Test on Numerical Variables

# %%
from scipy import stats
from scipy.stats import ttest_ind

# %% [markdown]
# #### Age

# %%
# Filtering data
churned_values = relevant_df[relevant_df['Churn'] == 1]['Age']
retained_values= relevant_df[relevant_df['Churn'] == 0]['Age']

# %%
# Age

stat, p = stats.ttest_ind(churned_values, retained_values)
churn_avg = churned_values.mean()
retained_avg = retained_values.mean()

print(f'Churn mean: {churn_avg}')
print(f'Retained mean: {retained_avg}')
print(f'Age p-value: {p:.6f}')
# Out:
# Churn mean: 44.83562315996075
# Retained mean: 37.40806330067822
# Age p-value: 0.000000

# %% [markdown]
# #### Balance

# %%
# Filtering data
churned_values_bal = relevant_df[relevant_df['Churn']  == 1]['Balance']
retained_values_bal = relevant_df[relevant_df['Churn'] == 0]['Balance']

# %%
stat, p = stats.ttest_ind(churned_values_bal, retained_values_bal)
churn_avg_bal = churned_values_bal.mean()
retained_avg_bal = retained_values_bal.mean()

print(f'Churn mean: {churn_avg_bal}')
print(f'Retained mean: {retained_avg_bal}')
print(f'Balance p-value: {p:.6f}')
# Out:
# Churn mean: 91109.47600588812
# Retained mean: 72742.75066314996
# Balance p-value: 0.000000

# %% [markdown]
# #### Credit Score

# %%
# Filtering data
churned_values_cs= relevant_df[relevant_df['Churn']== 1]['CreditScore']
retained_values_cs= relevant_df[relevant_df['Churn']== 0]['CreditScore']

# %%
stats, p = stats.ttest_ind(churned_values_cs, retained_values_cs)
churn_avg_cs= churned_values_cs.mean()
retained_avg_cs= retained_values_cs.mean()

print(f'Churn mean: {churn_avg_cs}')
print(f'Retained mean: {retained_avg_cs}')
print(f'Credit Score p-value: {p:.6f}')
# Out:
# Churn mean: 645.4146221786065
# Retained mean: 651.8378548103492
# Credit Score p-value: 0.007422
